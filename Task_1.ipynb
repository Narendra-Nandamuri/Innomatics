# %% [markdown]
# ### Problem 1

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Problem 2

# %%
if __name__ == '__main__':
    n = int(input().strip())
if n % 2 == 1:
    print("Weird")
elif 2 <= n <= 5:
    print("Not Weird")
elif 6 <= n <= 20:
    print("Weird")
else:
    print("Not Weird")
# Out:
# 3
# Weird

# %% [markdown]
# ### Problem 3

# %%
if __name__ == '__main__':
    a = int(input().strip())
    b = int(input().strip())
    print(a+b)
    print(a-b)
    print(a*b)
# Out:
# 2
# 3
# 5
# -1
# 6

# %% [markdown]
# ### Problem 4

# %%
if __name__ == '__main__':
    a = int(input().strip())
    b = int(input().strip())

    print(a // b)
    print(a / b)
# Out:
# 9
# 3
# 3
# 3.0

# %% [markdown]
# ### Problem 5

# %%
if __name__ == '__main__':
    n = int(input().strip())

    for i in range(n):
        print(i * i)
# Out:
# 3
# 0
# 1
# 4

# %% [markdown]
# ### Problem 6

# %%
def is_leap(year):
    leap = False
    if year % 4 != 0:
        return False
    elif year % 100 != 0:
        return True
    elif year % 400 == 0:
        return True
    return leap

year = int(input())
print(is_leap(year))
# Out:
# 1999
# False

# %% [markdown]
# ### Problem 7

# %%
if __name__ == '__main__':
    n = int(input())

    for i in range(1, n + 1):
        print(i, end="")
# Out:
# 3
# 123
